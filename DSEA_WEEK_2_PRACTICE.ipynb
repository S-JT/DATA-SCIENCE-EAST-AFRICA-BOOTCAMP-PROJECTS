# %% [markdown]
# <a href="https://colab.research.google.com/github/S-JT/DATA-SCIENCE-EAST-AFRICA-BOOTCAMP-PROJECTS/blob/main/DSEA_WEEK_2_PRACTICE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# STEP 1. The first step in data wrangling and data cleaning here is importing the neccessary data to process the data and to analyze its characteristics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from scipy import stats
from scipy.stats import pearsonr

# %% [markdown]
# STEP 2. In this second step, I have imported the weather data to be analyzed as illustrated below by defining my data for ease of running code as "df" and viewing the first 10 rows

# %%
#importing the dataset
path="/content/drive/MyDrive/DATASETS/1. Weather Data.csv"
df=pd.read_csv("/content/drive/MyDrive/DATASETS/1. Weather Data.csv")
df.head(10)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
# 5  1/1/2012 5:00    -1.4              -3.3         87                9
# 6  1/1/2012 6:00    -1.5              -3.1         89                7
# 7  1/1/2012 7:00    -1.4              -3.6         85                7
# 8  1/1/2012 8:00    -1.4              -3.6         85                9
# 9  1/1/2012 9:00    -1.3              -3.1         88               15
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# ...

# %% [markdown]
# STEP 3: In the step below, I have viewed the last 10 rows of the data to ascertain that my data has been sucessfully imported

# %%
df.tail(10)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8774  12/31/2012 14:00    -3.4              -5.7         84                6
# 8775  12/31/2012 15:00    -2.3              -4.6         84                9
# 8776  12/31/2012 16:00    -1.4              -4.0         82               13
# 8777  12/31/2012 17:00    -1.1              -3.3         85               19
# 8778  12/31/2012 18:00    -1.3              -3.1         88               17
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather
# 8774           11.3     100.57    Snow
# 8775            9.7     100.47    Snow
# ...

# %% [markdown]
# STEP 4: Definition of the characteristics (numerical and categorical) of the data at hand to show a statistical summary. Here, the function df.describe is used to show data types e.g
# 1. strings/ text (str) which are sentences
# 2. character(char) for single letters
# 3. integer(int) which are whole numbers
# 4. Float/real which are numbers containing decimal points or fractions and
# 5. boolean/bool which is a data type restricted to a Yes or a No statement.
# 6. Count indicates the number of data values in a set
# 7. NaN indicates values that are not numbers
# 8. The data types also includes frequency (freq), Mean, standard deviation(std), mediam mean and the percentiles (25%,50% and 75%) as well as the maximum(max) and minimum(min) values of each data sets
#
# the function(include=all) is used here to get the categorical variables which are
# - unique
# - top and
# -frequency
#
# where there is no need for this, the code will exclude these outputs.
#  From these findings, we can see that under the weather column, there are 50 unique instances out of the total number wheras the  top most occurene under weather is "mainly clear" indicating that this has been the main concesus in all of the dates documented and it has an occurency of 2106 times as indicated by its frequency.
#  Results indicate that the mean temperature for tis dataset was 8.798144 and the standard devition for the same was 11.687883.
#  If we look at the minimum recorded entries, the results indicate that the lowest visibility was 0.200000	whilw lowest wind speed was 0.
#  The table below shows all the results for all the other specific instances which can be used to draw conclusions where needed.

# %%
df.describe(include="all")
# Out:
#             Date/Time       Temp_C  Dew Point Temp_C    Rel Hum_%  \
# count            8784  8784.000000       8784.000000  8784.000000
# unique           8784          NaN               NaN          NaN
# top     1/1/2012 0:00          NaN               NaN          NaN
# freq                1          NaN               NaN          NaN
# mean              NaN     8.798144          2.555294    67.431694
# std               NaN    11.687883         10.883072    16.918881
# min               NaN   -23.300000        -28.500000    18.000000
# 25%               NaN     0.100000         -5.900000    56.000000
# 50%               NaN     9.300000          3.300000    68.000000
# 75%               NaN    18.800000         11.800000    81.000000
# max               NaN    33.000000         24.400000   100.000000
#
#         Wind Speed_km/h  Visibility_km    Press_kPa       Weather
# count       8784.000000    8784.000000  8784.000000          8784
# ...

# %%
df.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %% [markdown]
# STEP 5: DATA CLEANING
# In this step, I have identified any missing values/ NULL values by running the code as indicated below and the results will be displayed to be either 'True' or 'False'
# Instances where the word 'False' appera means that there are no missing values and vice versa.
# To get the number of missing values in a dataset, the second code calls out the number of missing values in each row to ease the wrangling process. Findings from this code shows that our dataset has no missing values identified.

# %%
df.isna()
# Out:
#       Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0         False   False             False      False            False
# 1         False   False             False      False            False
# 2         False   False             False      False            False
# 3         False   False             False      False            False
# 4         False   False             False      False            False
# ...         ...     ...               ...        ...              ...
# 8779      False   False             False      False            False
# 8780      False   False             False      False            False
# 8781      False   False             False      False            False
# 8782      False   False             False      False            False
# 8783      False   False             False      False            False
#
#       Visibility_km  Press_kPa  Weather
# 0             False      False    False
# 1             False      False    False
# ...

# %%
df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# month               0
# day                 0
# dtype: int64

# %%
df.info
# Out:
# <bound method DataFrame.info of              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# STEP 6: Checking for duplicate entries.
# Here, the code shown below is used to indicate if there are any entries that appear more than once. This ensures that before conclusions are made from the analysis of said data, we do not have entries that may create false results and conclusions. In this instance, the date and time should not be in duplicates because this instance only occurs once factually therefore any duplicates should be dropped.
# In this case, the results are "False" which indicates that there are no duplicates in this data set. If the results would have been "True' this would indicate instances where there are duplicate entries.

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Length: 8784, dtype: bool

# %% [markdown]
# STEP 7: IDENTIFYING OUTLIERS.
# Outliers are data points that fall outside the normal range of certain instances.
# These often portray a false idea of the ideal. Once the data types have been identified, the value counts can be used to identify instances which stand out.
# From the findings, there seems to be no outliers ince none of the occurences significanty differ from the whole dataset.

# %%
df["Temp_C"].value_counts()
# Out:
# Temp_C
#  16.6    65
#  1.1     58
#  0.8     47
#  1.5     45
#  19.3    44
#          ..
# -20.7     1
# -21.0     1
#  31.8     1
#  32.6     1
# -21.3     1
# Name: count, Length: 533, dtype: int64

# %%
df["Dew Point Temp_C"].value_counts()
# Out:
# Dew Point Temp_C
#  12.9    48
# -0.9     48
#  9.9     47
#  10.9    47
# -0.3     45
#          ..
# -25.5     1
# -26.0     1
# -21.6     1
# -24.0     1
#  21.8     1
# Name: count, Length: 489, dtype: int64

# %%
df["Rel Hum_%"].value_counts()
# Out:
# Rel Hum_%
# 68    210
# 83    202
# 81    195
# 71    194
# 59    192
#      ...
# 22      6
# 20      5
# 23      5
# 18      2
# 19      1
# Name: count, Length: 83, dtype: int64

# %%
df["Wind Speed_km/h"].value_counts()
# Out:
# Wind Speed_km/h
# 9     830
# 11    791
# 13    735
# 15    719
# 7     677
# 17    666
# 19    616
# 6     609
# 20    496
# 4     474
# 22    439
# 24    374
# 0     309
# 26    242
# 28    205
# 30    161
# 32    139
# 33     85
# 35     53
# 37     45
# 39     24
# 41     22
# 44     14
# 43     13
# 48     13
# 46     11
# 52      7
# 57      5
# 50      4
# 2       2
# 83      1
# 70      1
# 63      1
# 54      1
# Name: count, dtype: int64

# %%
df["Visibility_km"].value_counts()
# Out:
# Visibility_km
# 25.0    3324
# 48.3    2014
# 24.1    1921
# 19.3     281
# 16.1     224
# 9.7      181
# 12.9     174
# 6.4      129
# 8.0      122
# 4.8       79
# 4.0       55
# 2.4       50
# 3.2       42
# 11.3      36
# 1.2       28
# 2.0       28
# 1.6       25
# 0.6       16
# 2.8       15
# 1.0       11
# 3.6       11
# 0.2        8
# 0.8        7
# 0.4        3
# Name: count, dtype: int64

# %%
df["Press_kPa"].value_counts()
# Out:
# Press_kPa
# 101.13    69
# 101.36    57
# 100.69    56
# 101.06    54
# 100.65    54
#           ..
# 98.18      1
# 98.06      1
# 98.00      1
# 97.97      1
# 98.19      1
# Name: count, Length: 518, dtype: int64

# %%
df["Weather"].value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %% [markdown]
# STEP 8: DATA VISUALIZATION.
# This is where charts have been generated to illustrate relationships between varriables using different functions. These can be univariable, bivariable or multiple varried.

# %% [markdown]
# BOX PLOTS TO VISUALIZE NUMERICAL DATA.
# Here, the code below will be run to show relationships between different variables.
# From the findings below, there are no outliers from the comparison of the relationships between the general temperatures to dew point temperatures and real humidity.

# %%
sns.boxplot(x = "Temp_C", y = "Dew Point Temp_C", data = df)
# Out:
# <Axes: xlabel='Temp_C', ylabel='Dew Point Temp_C'>

# %%
sns.boxplot(x = "Temp_C", y = "Rel Hum_%", data = df)
# Out:
# <Axes: xlabel='Temp_C', ylabel='Rel Hum_%'>

# %% [markdown]
# SCATTER PLOTS: These are used to define relationships between two varriables, here, I want to check the relationship between visibility and weather.

# %%
y = df["Visibility_km"]
x = df["Weather"]
plt.scatter(x,y)
plt.title("Scatter plot of visibility vs weather")
plt.xlabel("Weather")
plt.ylabel("Visibility_km")
# Out:
# Text(0, 0.5, 'Visibility_km')

# %%
y = df["Wind Speed_km/h"]
x = df["Press_kPa"]
plt.scatter(x,y)
plt.title("Scatter plot of Wind Speed_km/h vs Press_kPa")
plt.xlabel("Wind Speed_km/h")
plt.ylabel("Press_kPa")
# Out:
# Text(0, 0.5, 'Press_kPa')

# %% [markdown]
# CORRELATION OF VARIABLES.
# Here, different varriables vorrelation is defined to determine interdependence. FOr instance, the code blow indicates how temperature and dew points relate.
# Findings indicate that these two varriables are interdependent and has a high positive linear relationship. With the increase in temperatures, the dew point temperatures also increase.
# In the secod example, when we look at the relationship between temperature and visibility also indicates a positive correlation.

# %%
sns.regplot(x="Temp_C", y = "Dew Point Temp_C", data =df)
plt.ylim(0,)
# Out:
# (0.0, 27.044999999999998)

# %%
sns.regplot(x="Temp_C", y = "Visibility_km", data =df)
plt.ylim(0,)
# Out:
# (0.0, 50.705)

# %% [markdown]
# The pearson correlation between different variables can be calculated using the scipy function as indicated below:
# The table below indicates how each varriable relates to each other. Where the p value is nearer to 1, that is indicative of a stronger correlation and vice versa.
#
# For example, there is a higher correlation between "Temp_C" and "Dew Point Temp_C" and a significantly lower correlation /negative correlation between "Press_kPa" and "Wind Speed_km/h"

# %%
df_numeric = df.select_dtypes(include=[float,int])
corr_matrix = df_numeric.corr()
corr_matrix
# Out:
#                     Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Temp_C            1.000000          0.932714  -0.220182        -0.061876
# Dew Point Temp_C  0.932714          1.000000   0.139494        -0.095685
# Rel Hum_%        -0.220182          0.139494   1.000000        -0.092743
# Wind Speed_km/h  -0.061876         -0.095685  -0.092743         1.000000
# Visibility_km     0.273455          0.050813  -0.633683         0.004883
# Press_kPa        -0.236389         -0.320616  -0.231424        -0.356613
#
#                   Visibility_km  Press_kPa
# Temp_C                 0.273455  -0.236389
# Dew Point Temp_C       0.050813  -0.320616
# Rel Hum_%             -0.633683  -0.231424
# Wind Speed_km/h        0.004883  -0.356613
# Visibility_km          1.000000   0.231847
# Press_kPa              0.231847   1.000000

# %%
sns.regplot (x="Press_kPa", y = "Wind Speed_km/h", data =df)
plt.ylim(0,)
# Out:
# (0.0, 87.15)

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('correlation heatmap')
plt.show()

# %% [markdown]
# STEP 8: WEATHER PATTERNS.
# In this step, an analysis of weather trends during the year. In this case, let us classify the weather types first by finding the value counts of all weather patterns.
# The second code will then plot these weather occurences visa vis the time they occur in to see how the seasons changed over time.
# Findings indicate that the frequent weather occurences during that year was "mainly clear and mostly cloudy and fewer occurences of snow, fog and rains as indicated in the output of counts below.

# %%
df["Weather"].value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
#df_dates = ('Date/Time')
#df_dates['Day'] = df_dates['Date/Time'].dt.day
#print

# %% [markdown]
# Using pandas library, we can extract the year, month and date.
# First, we will have a look at the types of data in each column using the info command.
# Findings indicate that the column has data of the object format. We therefore need to convert this to a date time frat using the datetime command.

# %%
df=pd.read_csv("/content/drive/MyDrive/DATASETS/1. Weather Data.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
import datetime as dt

# %%
df["Date/Time"]

# %% [markdown]
# From the code results above, the data type is an object therefore I will run code to convert it to date time format as indicated below: and extract different days and months in order to facilitate asessment of trends over different months.

# %%
df["Date/Time"] = pd.to_datetime(df['Date/Time'])
df['Date/Time']
# Out:
# 0      2012-01-01 00:00:00
# 1      2012-01-01 01:00:00
# 2      2012-01-01 02:00:00
# 3      2012-01-01 03:00:00
# 4      2012-01-01 04:00:00
#                ...
# 8779   2012-12-31 19:00:00
# 8780   2012-12-31 20:00:00
# 8781   2012-12-31 21:00:00
# 8782   2012-12-31 22:00:00
# 8783   2012-12-31 23:00:00
# Name: Date/Time, Length: 8784, dtype: datetime64[ns]

# %%
df['Date/Time'].dt.year
# Out:
# 0       2012
# 1       2012
# 2       2012
# 3       2012
# 4       2012
#         ...
# 8779    2012
# 8780    2012
# 8781    2012
# 8782    2012
# 8783    2012
# Name: Date/Time, Length: 8784, dtype: int32

# %%
df['Date/Time'].dt.month
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 8779    12
# 8780    12
# 8781    12
# 8782    12
# 8783    12
# Name: Date/Time, Length: 8784, dtype: int32

# %%
df['Date/Time'].dt.day
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 8779    31
# 8780    31
# 8781    31
# 8782    31
# 8783    31
# Name: Date/Time, Length: 8784, dtype: int32

# %%
#df['year'] = df['Date/Time'].dt.year
#df['month'] = df['Date/Time'].dt.month
#df['day'] = df['Date/Time'].dt.day
#df['Date/Time']

# %%
df['month'] = df['Date/Time'].dt.month
df['day'] = df['Date/Time'].dt.day
df['Date/Time']
# Out:
# 0      2012-01-01 00:00:00
# 1      2012-01-01 01:00:00
# 2      2012-01-01 02:00:00
# 3      2012-01-01 03:00:00
# 4      2012-01-01 04:00:00
#                ...
# 8779   2012-12-31 19:00:00
# 8780   2012-12-31 20:00:00
# 8781   2012-12-31 21:00:00
# 8782   2012-12-31 22:00:00
# 8783   2012-12-31 23:00:00
# Name: Date/Time, Length: 8784, dtype: datetime64[ns]

# %% [markdown]
# SCATTER PLOTS FOR VARIOUS WEATHER ASPECTS:
# 1. An analysis of humidity throughout the year by using the matplotlib library code  shows that the humidity between January and March was significntly higher than the months between march and July then there is a slight increase as the months progress to December.

# %%
y = df["Rel Hum_%"]
x = df["Date/Time"]
plt.scatter(x,y)
plt.title("Scatter Plot of Humidity vs Date")
plt.xlabel("Rel Hum_%")
plt.ylabel("Date/Time")
# Out:
# Text(0, 0.5, 'Date/Time')

# %% [markdown]
# A scatter plot of the Temerature varriable indicates a gradual increase in tempeartures from January to July and a gradual decrease from July to December. This is indicative that the hotest month during the year 2012 was July.

# %%
y = df["Temp_C"]
x = df["Date/Time"]
plt.scatter(x,y)
plt.title("Scatter Plot of Temperature vs Date")
plt.xlabel("Temp_C")
plt.ylabel("Date/Time")
# Out:
# Text(0, 0.5, 'Date/Time')

# %% [markdown]
# In this next step, let us look at the relationship between the two varriables above by plotting a regression model of Temperature vs Humidity in the code below:
#  Findings from this code shows that these two varriables have a negative correlation to each other therefore high humidity levels significantly reduces the temperature levels.

# %%
sns.regplot(x = "Temp_C", y = "Rel Hum_%", data = df)
plt.ylim(0,)
# Out:
# (0.0, 104.1)

# %%
y = df["Dew Point Temp_C"]
x = df["Date/Time"]
plt.scatter(x,y)
plt.title("Scatter Plot of Dew point vs Date")
plt.xlabel("Dew Point Temp_C")
plt.ylabel("Date/Time")
# Out:
# Text(0, 0.5, 'Date/Time')

# %%
y = df["Temp_C"]
x = df["Press_kPa"]
plt.scatter(x,y)
plt.title("Scatter Plot of Temperature vs Atmospheric pressure")
plt.xlabel("Temp_C")
plt.ylabel("Press_kPa")
# Out:
# Text(0, 0.5, 'Press_kPa')

# %%
y = df["Rel Hum_%"]
x = df["Press_kPa"]
plt.scatter(x,y)
plt.title("Scatter Plot of Humidity vs Atmospheric pressure")
plt.xlabel("Rel Hum_%")
plt.ylabel("Press_kPa")
# Out:
# Text(0, 0.5, 'Press_kPa')

# %% [markdown]
# IDENTIFYING ANOMALIES IN THE DATASET.
# Here, anomalies are data that fall out of their normal behaviour. In this dataset however, there are no anomalies identified seeing as all the varriables fall within closer cluster values.

# %%
df.head(2)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather  month  day
# 0            8.0     101.24     Fog      1    1
# 1            8.0     101.24     Fog      1    1

# %% [markdown]
# RECOMMENDATIONS FOR FURTHER ANALYSIS:
# this dataset has is important in analysis of data. However, if the dataset had more information such as latitude and longitude, this would further improve the accuracy of this set of data in analysis of aspects such as Atmospheric pressure. Aspects such as sunshine duration and precipitation should also be considered.
# Aspects under the weather column should also be further analyzed by separating and plotting to see the occurences of spcific aspects such as drizzles, percentage cloud cover etc.
